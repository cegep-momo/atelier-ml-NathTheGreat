# %%
import pandas as pnd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf
import keras

tf.config.set_visible_devices([], 'GPU')

#Définition de la longueur et de la largeur de l'image
LONGUEUR_IMAGE = 28
LARGEUR_IMAGE = 28

#Chargement des images
observations_entrainement = pnd.read_csv('datas/fashion-mnist_train.csv')

# %%
#On exclut la première colonne (les labels) pour constituer un tableau de pixels
X = np.array(observations_entrainement.iloc[:, 1:])

premiereImage = X[0]
premiereImage = premiereImage.reshape([LONGUEUR_IMAGE,LARGEUR_IMAGE])
plt.imshow(premiereImage)
plt.show()

# %%
#On crée des catégories à l'aide du module Keras
y = keras.utils.to_categorical(np.array(observations_entrainement.iloc[:,0]))
#Répartition des données d'entrainement en données d'apprentissage et données de validation
#80% de donnée d'apprentissage et 20% de donnée de validation
X_apprentissage, X_validation, y_apprentissage, y_validation = train_test_split(X, y, test_size=0.2, random_state=13)

# %%
# On redimensionne les images au format 28*28 et on réalise un scaling sur les données des pixels
X_apprentissage = X_apprentissage.reshape(X_apprentissage.shape[0], 
                                          LARGEUR_IMAGE, 
                                          LONGUEUR_IMAGE, 1)
X_apprentissage = X_apprentissage.astype('float32')
X_apprentissage /= 255

X_validation = X_validation.reshape(X_validation.shape[0], 
                                    LARGEUR_IMAGE, 
                                    LONGUEUR_IMAGE, 1)
X_validation = X_validation.astype('float32')
X_validation /= 255

# %%
#Preparation des données de tests
observations_test = pnd.read_csv('datas/fashion-mnist_test.csv')
X_test = np.array(observations_test.iloc[:, 1:])
y_test = tf.keras.utils.to_categorical(np.array(observations_test.iloc[:, 0]))
X_test = X_test.reshape(X_test.shape[0], 
                        LARGEUR_IMAGE, 
                        LONGUEUR_IMAGE, 1)
X_test = X_test.astype('float32')
X_test /= 255

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Input
from keras.layers import Conv2D, MaxPooling2D

# On spécifie les dimensions de l'image d'entrée
dimentionImage = (LARGEUR_IMAGE, LONGUEUR_IMAGE, 1)

# On crée le réseau de neurones couche par couche
reseauNeurone1Convolution = Sequential()

# Ajout de la couche d'entrée
reseauNeurone1Convolution.add(Input(shape=dimentionImage))

#1- Ajout de la couche de convolution comportant
# 32 filtres de de taille 3x3 (Kernel) parcourant l'image
# Une fonction d'activation de type ReLU (Rectified Linear Activation)
# Une image d'entrée de 28px * 28 px 
reseauNeurone1Convolution.add(Conv2D(32, 
                                     kernel_size=(3, 3), 
                                     activation='relu'))

#2- Définition de la fonction de pooling avec une fenêtre de 2px sur 2 px
reseauNeurone1Convolution.add(MaxPooling2D(pool_size=(2, 2)))

#3- Ajout d'une fonction d'ignorance
reseauNeurone1Convolution.add(Dropout(0.2))

#5 - On transforme en une seule ligne
reseauNeurone1Convolution.add(Flatten())

#6 - Ajout d'un réseau de neurones composé de 128 neurones avec 
# une fonction d'activation de type ReLU
reseauNeurone1Convolution.add(Dense(128, activation='relu'))

#7 - Ajout d'un réseau de neurones composé de 10 neurones avec une 
# fonction d'activation de type softmax
reseauNeurone1Convolution.add(Dense(10, activation='softmax'))

# %%
reseauNeurone1Convolution.compile(loss=keras.losses.categorical_crossentropy, 
                                  optimizer=tf.keras.optimizers.Adam(), 
                                  metrics=['accuracy'])

# %%
historique_apprentissage = reseauNeurone1Convolution.fit(
    X_apprentissage, 
    y_apprentissage,
    batch_size=256,
    epochs=10,
    verbose=1,
    validation_data=(X_validation, y_validation))
# Out:
# Epoch 1/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 13s 59ms/step - accuracy: 0.8016 - loss: 0.5645 - val_accuracy: 0.8561 - val_loss: 0.4125
# Epoch 2/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 11s 57ms/step - accuracy: 0.8675 - loss: 0.3786 - val_accuracy: 0.8801 - val_loss: 0.3483
# Epoch 3/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 56ms/step - accuracy: 0.8834 - loss: 0.3293 - val_accuracy: 0.8858 - val_loss: 0.3278
# Epoch 4/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 11s 58ms/step - accuracy: 0.8945 - loss: 0.2984 - val_accuracy: 0.8935 - val_loss: 0.3015
# Epoch 5/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 11s 56ms/step - accuracy: 0.9020 - loss: 0.2780 - val_accuracy: 0.8937 - val_loss: 0.2999
# Epoch 6/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 11s 57ms/step - accuracy: 0.9069 - loss: 0.2629 - val_accuracy: 0.9013 - val_loss: 0.2742
# Epoch 7/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 11s 56ms/step - accuracy: 0.9112 - loss: 0.2476 - val_accuracy: 0.9038 - val_loss: 0.2665
# Epoch 8/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 11s 57ms/step - accuracy: 0.9165 - loss: 0.2332 - val_accuracy: 0.9064 - val_loss: 0.2653
# Epoch 9/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 11s 59ms/step - accuracy: 0.9211 - loss: 0.2232 - val_accuracy: 0.9078 - val_loss: 0.2578
# Epoch 10/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 54ms/step - accuracy: 0.9224 - loss: 0.2137 - val_accuracy: 0.9114 - val_loss: 0.2459

# %%
evaluation = reseauNeurone1Convolution.evaluate(X_test, y_test, verbose=0)
print('Erreur:', evaluation[0])
print('Précision:', evaluation[1])
# Out:
# Erreur: 0.23528510332107544
# Précision: 0.9162999987602234

# %%
plt.plot(historique_apprentissage.history['accuracy'])
plt.plot(historique_apprentissage.history['val_accuracy'])
plt.title('Précision du modèle')
plt.ylabel('Précision')
plt.xlabel('Epoch')
plt.legend(['Apprentissage', 'Test'], loc='upper left')
plt.show()
# Plot training & validation loss values
plt.plot(historique_apprentissage.history['loss'])
plt.plot(historique_apprentissage.history['val_loss'])
plt.title('Erreur')
plt.ylabel('Erreur')
plt.xlabel('Epoch')
plt.legend(['Apprentissage', 'Test'], loc='upper left')
plt.show()

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

generateur_images = tf.keras.preprocessing.image.ImageDataGenerator(
    rotation_range=8,
    width_shift_range=0.08,
    shear_range=0.3,
    height_shift_range=0.08,
    zoom_range=0.08)

# %%
nouvelles_images_apprentissage = generateur_images.flow(
    X_apprentissage, 
    y_apprentissage,
    batch_size=256)

nouvelles_images_validation = generateur_images.flow(
    X_validation, 
    y_validation,
    batch_size=256)

historique_apprentissage = reseauNeurone1Convolution.fit(
    nouvelles_images_apprentissage,
    steps_per_epoch=48000//256,
    epochs=50,
    validation_data=nouvelles_images_validation,
    validation_steps=12000//256,
    verbose=1 )

evaluation = reseauNeurone1Convolution.evaluate(X_test, y_test, verbose=0)

print('Erreur :', evaluation[0])
print('Précision:', evaluation[1])
# Out:
# Epoch 1/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 25s 132ms/step - accuracy: 0.8255 - loss: 0.4664 - val_accuracy: 0.8419 - val_loss: 0.4222
# Epoch 2/50
#   1/187 ━━━━━━━━━━━━━━━━━━━━ 12s 65ms/step - accuracy: 0.8125 - loss: 0.5423
# /home/vscode/.local/lib/python3.12/site-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.8125 - loss: 0.5423 - val_accuracy: 0.8399 - val_loss: 0.4241
# Epoch 3/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 25s 131ms/step - accuracy: 0.8471 - loss: 0.4143 - val_accuracy: 0.8508 - val_loss: 0.3944
# Epoch 4/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - accuracy: 0.8516 - loss: 0.4207 - val_accuracy: 0.8533 - val_loss: 0.3968
# Epoch 5/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 24s 129ms/step - accuracy: 0.8535 - loss: 0.3915 - val_accuracy: 0.8583 - val_loss: 0.3756
# Epoch 6/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.8633 - loss: 0.3604 - val_accuracy: 0.8597 - val_loss: 0.3778
# Epoch 7/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 23s 125ms/step - accuracy: 0.8604 - loss: 0.3781 - val_accuracy: 0.8632 - val_loss: 0.3646
# Epoch 8/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - accuracy: 0.8672 - loss: 0.3383 - val_accuracy: 0.8658 - val_loss: 0.3642
# Epoch 9/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 22s 118ms/step - accuracy: 0.8640 - loss: 0.3646 - val_accuracy: 0.8681 - val_loss: 0.3601
# Epoch 10/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.8477 - loss: 0.4121 - val_accuracy: 0.8665 - val_loss: 0.3603
# Epoch 11/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 22s 117ms/step - accuracy: 0.8658 - loss: 0.3607 - val_accuracy: 0.8647 - val_loss: 0.3567
# Epoch 12/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.8633 - loss: 0.3708 - val_accuracy: 0.8676 - val_loss: 0.3612
# Epoch 13/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 23s 122ms/step - accuracy: 0.8689 - loss: 0.3503 - val_accuracy: 0.8724 - val_loss: 0.3431
# Epoch 14/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.8750 - loss: 0.3003 - val_accuracy: 0.8729 - val_loss: 0.3451
# Epoch 15/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 22s 116ms/step - accuracy: 0.8744 - loss: 0.3405 - val_accuracy: 0.8795 - val_loss: 0.3355
# Epoch 16/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.8438 - loss: 0.3606 - val_accuracy: 0.8747 - val_loss: 0.3374
# Epoch 17/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 22s 117ms/step - accuracy: 0.8758 - loss: 0.3352 - val_accuracy: 0.8780 - val_loss: 0.3345
# Epoch 18/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.8828 - loss: 0.3302 - val_accuracy: 0.8792 - val_loss: 0.3265
# Epoch 19/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 22s 116ms/step - accuracy: 0.8771 - loss: 0.3343 - val_accuracy: 0.8761 - val_loss: 0.3368
# Epoch 20/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.8828 - loss: 0.3358 - val_accuracy: 0.8772 - val_loss: 0.3323
# Epoch 21/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 22s 117ms/step - accuracy: 0.8807 - loss: 0.3217 - val_accuracy: 0.8782 - val_loss: 0.3203
# Epoch 22/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.8594 - loss: 0.3520 - val_accuracy: 0.8803 - val_loss: 0.3273
# Epoch 23/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 23s 121ms/step - accuracy: 0.8795 - loss: 0.3219 - val_accuracy: 0.8787 - val_loss: 0.3251
# Epoch 24/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - accuracy: 0.8633 - loss: 0.3602 - val_accuracy: 0.8796 - val_loss: 0.3227
# Epoch 25/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 26s 140ms/step - accuracy: 0.8817 - loss: 0.3169 - val_accuracy: 0.8858 - val_loss: 0.3138
# Epoch 26/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - accuracy: 0.8633 - loss: 0.3531 - val_accuracy: 0.8853 - val_loss: 0.3159
# Epoch 27/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 25s 133ms/step - accuracy: 0.8854 - loss: 0.3094 - val_accuracy: 0.8837 - val_loss: 0.3143
# Epoch 28/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.8828 - loss: 0.3355 - val_accuracy: 0.8821 - val_loss: 0.3161
# Epoch 29/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 31s 164ms/step - accuracy: 0.8854 - loss: 0.3069 - val_accuracy: 0.8840 - val_loss: 0.3098
# Epoch 30/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.8633 - loss: 0.2888 - val_accuracy: 0.8860 - val_loss: 0.3101
# Epoch 31/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 30s 162ms/step - accuracy: 0.8875 - loss: 0.3056 - val_accuracy: 0.8850 - val_loss: 0.3089
# Epoch 32/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.8672 - loss: 0.3283 - val_accuracy: 0.8839 - val_loss: 0.3121
# Epoch 33/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 27s 142ms/step - accuracy: 0.8871 - loss: 0.3046 - val_accuracy: 0.8893 - val_loss: 0.3057
# Epoch 34/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.8789 - loss: 0.3676 - val_accuracy: 0.8888 - val_loss: 0.3043
# Epoch 35/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 26s 136ms/step - accuracy: 0.8895 - loss: 0.3005 - val_accuracy: 0.8869 - val_loss: 0.2984
# Epoch 36/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.8789 - loss: 0.2941 - val_accuracy: 0.8866 - val_loss: 0.3047
# Epoch 37/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 26s 136ms/step - accuracy: 0.8892 - loss: 0.2970 - val_accuracy: 0.8899 - val_loss: 0.2978
# Epoch 38/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.8867 - loss: 0.2979 - val_accuracy: 0.8895 - val_loss: 0.3031
# Epoch 39/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 25s 135ms/step - accuracy: 0.8902 - loss: 0.2958 - val_accuracy: 0.8941 - val_loss: 0.2915
# Epoch 40/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.8945 - loss: 0.3247 - val_accuracy: 0.8923 - val_loss: 0.2886
# Epoch 41/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 25s 134ms/step - accuracy: 0.8914 - loss: 0.2940 - val_accuracy: 0.8902 - val_loss: 0.2912
# Epoch 42/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.8906 - loss: 0.3512 - val_accuracy: 0.8892 - val_loss: 0.2972
# Epoch 43/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 25s 133ms/step - accuracy: 0.8928 - loss: 0.2874 - val_accuracy: 0.8886 - val_loss: 0.3012
# Epoch 44/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.8828 - loss: 0.3457 - val_accuracy: 0.8894 - val_loss: 0.3010
# Epoch 45/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 25s 134ms/step - accuracy: 0.8936 - loss: 0.2866 - val_accuracy: 0.8910 - val_loss: 0.2936
# Epoch 46/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - accuracy: 0.9023 - loss: 0.2594 - val_accuracy: 0.8912 - val_loss: 0.2982
# Epoch 47/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 25s 134ms/step - accuracy: 0.8941 - loss: 0.2845 - val_accuracy: 0.8916 - val_loss: 0.2955
# Epoch 48/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - accuracy: 0.9180 - loss: 0.2827 - val_accuracy: 0.8967 - val_loss: 0.2878
# Epoch 49/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 26s 137ms/step - accuracy: 0.8954 - loss: 0.2842 - val_accuracy: 0.8925 - val_loss: 0.2916
# Epoch 50/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.8906 - loss: 0.3184 - val_accuracy: 0.8911 - val_loss: 0.2961
# Erreur : 0.23624743521213531
# Précision: 0.9180999994277954

# %%
#Sauvegarde du modèle
# Serialisation du modèle 
model_json = reseauNeurone1Convolution.to_json() 
with open("modele/modele.json", "w") as json_file:
    json_file.write(model_json)
    
# Serialisation des poids
reseauNeurone1Convolution.save_weights("modele/modele.weights.h5")
print("Modèle sauvegardé !")
# Out:
# Modèle sauvegardé !

# %%
from keras.layers import BatchNormalization

reseauNeurones4Convolution = Sequential()

reseauNeurones4Convolution.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=dimentionImage))
reseauNeurones4Convolution.add(BatchNormalization())
reseauNeurones4Convolution.add(Conv2D(32, kernel_size=(3, 3), activation='relu'))
reseauNeurones4Convolution.add(BatchNormalization())
reseauNeurones4Convolution.add(MaxPooling2D(pool_size=(2, 2)))
reseauNeurones4Convolution.add(Dropout(0.25))

reseauNeurones4Convolution.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
reseauNeurones4Convolution.add(BatchNormalization())
reseauNeurones4Convolution.add(Dropout(0.25))

reseauNeurones4Convolution.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
reseauNeurones4Convolution.add(BatchNormalization())
reseauNeurones4Convolution.add(MaxPooling2D(pool_size=(2, 2)))
reseauNeurones4Convolution.add(Dropout(0.25))

reseauNeurones4Convolution.add(Flatten())
reseauNeurones4Convolution.add(Dense(512, activation='relu'))
reseauNeurones4Convolution.add(BatchNormalization())
reseauNeurones4Convolution.add(Dropout(0.5))

reseauNeurones4Convolution.add(Dense(128, activation='relu'))
reseauNeurones4Convolution.add(BatchNormalization())
reseauNeurones4Convolution.add(Dropout(0.5))

reseauNeurones4Convolution.add(Dense(10, activation='softmax'))

# %%
reseauNeurones4Convolution.compile(loss=keras.losses.categorical_crossentropy, 
                                  optimizer=tf.keras.optimizers.Adam(), 
                                  metrics=['accuracy'])

historique_apprentissage = reseauNeurones4Convolution.fit(
    X_apprentissage, 
    y_apprentissage,
    batch_size=256,
    epochs=10,
    verbose=1,
    validation_data=(X_validation, y_validation))
# Out:
# Epoch 1/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 78s 383ms/step - accuracy: 0.7400 - loss: 0.7435 - val_accuracy: 0.1657 - val_loss: 3.2245
# Epoch 2/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 69s 368ms/step - accuracy: 0.8446 - loss: 0.4368 - val_accuracy: 0.4712 - val_loss: 1.9428
# Epoch 3/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 69s 368ms/step - accuracy: 0.8719 - loss: 0.3627 - val_accuracy: 0.7777 - val_loss: 0.6873
# Epoch 4/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 71s 377ms/step - accuracy: 0.8846 - loss: 0.3262 - val_accuracy: 0.8947 - val_loss: 0.2929
# Epoch 5/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 77s 407ms/step - accuracy: 0.8928 - loss: 0.3030 - val_accuracy: 0.8995 - val_loss: 0.2729
# Epoch 6/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 72s 384ms/step - accuracy: 0.9010 - loss: 0.2795 - val_accuracy: 0.8972 - val_loss: 0.2698
# Epoch 7/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 77s 411ms/step - accuracy: 0.9060 - loss: 0.2654 - val_accuracy: 0.9122 - val_loss: 0.2505
# Epoch 8/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 75s 399ms/step - accuracy: 0.9086 - loss: 0.2564 - val_accuracy: 0.9067 - val_loss: 0.2609
# Epoch 9/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 76s 402ms/step - accuracy: 0.9109 - loss: 0.2477 - val_accuracy: 0.9137 - val_loss: 0.2317
# Epoch 10/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 75s 400ms/step - accuracy: 0.9147 - loss: 0.2358 - val_accuracy: 0.9148 - val_loss: 0.2346

# %%
#Sauvegarde du modèle
# Serialisation du modèle 
model_json = reseauNeurones4Convolution.to_json() 
with open("modele/modele.json", "w") as json_file:
    json_file.write(model_json)
    
# Serialisation des poids
reseauNeurones4Convolution.save_weights("modele/modele.weights.h5")
print("Modèle sauvegardé !")
# Out:
# Modèle sauvegardé !
